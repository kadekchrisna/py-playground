# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img = plt.imread(r'/Users/kadekchresna/project/py/py-playground/np/bird.png')

# %%
img.shape
# Out:
# (1440, 2560, 4)

# %%
img[:,:,1]
# Out:
# array([[0.3254902 , 0.30980393, 0.32941177, ..., 0.78431374, 0.78431374,
#         0.78431374],
#        [0.2784314 , 0.22352941, 0.2       , ..., 0.78431374, 0.78431374,
#         0.78431374],
#        [0.19607843, 0.19215687, 0.19607843, ..., 0.78431374, 0.78431374,
#         0.78431374],
#        ...,
#        [0.50980395, 0.50980395, 0.50980395, ..., 0.654902  , 0.64705884,
#         0.64705884],
#        [0.49411765, 0.49411765, 0.49411765, ..., 0.6627451 , 0.65882355,
#         0.65882355],
#        [0.48235294, 0.48235294, 0.48235294, ..., 0.6666667 , 0.6627451 ,
#         0.6666667 ]], dtype=float32)

# %%
plt.imshow(img[:,:,0])

# %%
plt.imshow(img[:,:,1])

# %%
plt.imshow(img[:,:,2])

# %%
plt.imshow(img)

# %%
plt.imshow(img[:,:,2])
img[0:,:,]
img
# Out:
# array([[[0.50980395, 0.3254902 , 0.22352941, 1.        ],
#         [0.49411765, 0.30980393, 0.20784314, 1.        ],
#         [0.5137255 , 0.32941177, 0.22745098, 1.        ],
#         ...,
#         [0.5921569 , 0.78431374, 0.9137255 , 1.        ],
#         [0.5921569 , 0.78431374, 0.9137255 , 1.        ],
#         [0.5921569 , 0.78431374, 0.9137255 , 1.        ]],
#
#        [[0.4627451 , 0.2784314 , 0.1764706 , 1.        ],
#         [0.40392157, 0.22352941, 0.12156863, 1.        ],
#         [0.38431373, 0.2       , 0.09803922, 1.        ],
#         ...,
#         [0.5921569 , 0.78431374, 0.9137255 , 1.        ],
#         [0.5921569 , 0.78431374, 0.9137255 , 1.        ],
#         [0.5921569 , 0.78431374, 0.9137255 , 1.        ]],
#
#        [[0.3764706 , 0.19607843, 0.09411765, 1.        ],
#         [0.3647059 , 0.19215687, 0.08627451, 1.        ],
#         [0.3764706 , 0.19607843, 0.09411765, 1.        ],
#         ...,
# ...

# %%
img.shape[0]
# Out:
# 1440

# %%
np.arange(img.shape[0])[::-1]
# Out:
# array([1439, 1438, 1437, ...,    2,    1,    0])

# %%
img
# Out:
# array([[[0.50980395, 0.3254902 , 0.22352941, 1.        ],
#         [0.49411765, 0.30980393, 0.20784314, 1.        ],
#         [0.5137255 , 0.32941177, 0.22745098, 1.        ],
#         ...,
#         [0.5921569 , 0.78431374, 0.9137255 , 1.        ],
#         [0.5921569 , 0.78431374, 0.9137255 , 1.        ],
#         [0.5921569 , 0.78431374, 0.9137255 , 1.        ]],
#
#        [[0.4627451 , 0.2784314 , 0.1764706 , 1.        ],
#         [0.40392157, 0.22352941, 0.12156863, 1.        ],
#         [0.38431373, 0.2       , 0.09803922, 1.        ],
#         ...,
#         [0.5921569 , 0.78431374, 0.9137255 , 1.        ],
#         [0.5921569 , 0.78431374, 0.9137255 , 1.        ],
#         [0.5921569 , 0.78431374, 0.9137255 , 1.        ]],
#
#        [[0.3764706 , 0.19607843, 0.09411765, 1.        ],
#         [0.3647059 , 0.19215687, 0.08627451, 1.        ],
#         [0.3764706 , 0.19607843, 0.09411765, 1.        ],
#         ...,
# ...

# %%
img2 = img[np.array([1439,1438]),:,:]
# img2 = img[2,:,:]
img2
# Out:
# array([[[0.63529414, 0.48235294, 0.21960784, 1.        ],
#         [0.63529414, 0.48235294, 0.21960784, 1.        ],
#         [0.63529414, 0.48235294, 0.21960784, 1.        ],
#         ...,
#         [0.9137255 , 0.6666667 , 0.3019608 , 1.        ],
#         [0.91764706, 0.6627451 , 0.30980393, 1.        ],
#         [0.92156863, 0.6666667 , 0.3137255 , 1.        ]],
#
#        [[0.64705884, 0.49411765, 0.23137255, 1.        ],
#         [0.64705884, 0.49411765, 0.23137255, 1.        ],
#         [0.64705884, 0.49411765, 0.23137255, 1.        ],
#         ...,
#         [0.9098039 , 0.6627451 , 0.29803923, 1.        ],
#         [0.9137255 , 0.65882355, 0.30588236, 1.        ],
#         [0.9137255 , 0.65882355, 0.30588236, 1.        ]]], dtype=float32)

# %%
img2 = img[::-1]
img2
# Out:
# array([[[0.63529414, 0.48235294, 0.21960784, 1.        ],
#         [0.63529414, 0.48235294, 0.21960784, 1.        ],
#         [0.63529414, 0.48235294, 0.21960784, 1.        ],
#         ...,
#         [0.9137255 , 0.6666667 , 0.3019608 , 1.        ],
#         [0.91764706, 0.6627451 , 0.30980393, 1.        ],
#         [0.92156863, 0.6666667 , 0.3137255 , 1.        ]],
#
#        [[0.64705884, 0.49411765, 0.23137255, 1.        ],
#         [0.64705884, 0.49411765, 0.23137255, 1.        ],
#         [0.64705884, 0.49411765, 0.23137255, 1.        ],
#         ...,
#         [0.9098039 , 0.6627451 , 0.29803923, 1.        ],
#         [0.9137255 , 0.65882355, 0.30588236, 1.        ],
#         [0.9137255 , 0.65882355, 0.30588236, 1.        ]],
#
#        [[0.6627451 , 0.50980395, 0.24705882, 1.        ],
#         [0.6627451 , 0.50980395, 0.24705882, 1.        ],
#         [0.6627451 , 0.50980395, 0.24705882, 1.        ],
#         ...,
# ...

# %%
img.shape
# Out:
# (1440, 2560, 4)

# %%
img2.shape
# Out:
# (1440, 2560, 4)

# %%
img2 = img[np.arange(img.shape[0])[::-1],:,:]

# %%
img2.shape
# Out:
# (1440, 2560, 4)

# %%
plt.imshow(img)

# %%
plt.imshow(img2)

# %%
img2 = img[:,::-1,]
plt.imshow(img2)

# %%
img2 = img.copy()
img2[100:500,1000:2000,0] = 0
img2[100:500,1000:2000,1] = 0
img2[100:500,1000:2000,2] = 255


plt.imshow(img2)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(img2)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
